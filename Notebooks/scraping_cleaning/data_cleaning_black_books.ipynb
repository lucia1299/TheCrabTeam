# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
path = 'drive/MyDrive/'

# %%
df1 = pd.read_csv(path + 'epstein_black_book.csv', usecols=['Name','Type', 'City', 'Associated Entity', 'Associated Terms'])
df2 = pd.read_csv(path + 'epstein_black_book2.csv', usecols=['Name','Type', 'City', 'Associated Entity', 'Associated Terms'])

# %%
df1
# Out:
#                    Name           Type              City  \
# 0     301 East 66th St.  Miscellaneous          New York
# 1           Dan Abraham         Person          New York
# 2       Frederick Adler         Person   West Palm Beach
# 3            Cath Adler         Person   West Palm Beach
# 4          Aero Leasing         Entity    Zurich, Geneva
# ..                  ...            ...               ...
# 371          Fred Yaffe         Person  Bloomfield Hills
# 372  Dimitri Yugoslavie         Person          New York
# 373         Barry Zelin         Person          New York
# 374       Ira Zicherman         Person          Brooklyn
# 375      Mort Zucherman         Person          New York
#
#           Associated Entity Associated Terms
# 0                       NaN              NaN
# 1          Thompson Medical              NaN
# 2    Venad Management, Inc.              NaN
# 3    Venad Management, Inc.              NaN
# 4                       NaN              NaN
# ...

# %%
df2
# Out:
#                     Name    Type      City Associated Terms  \
# 0                    NaN     NaN       NaN              NaN
# 1                   Abby  Person       NaN              NaN
# 2             John Agnew  Person    London              NaN
# 3     Joanna Abousleiman  Person       NaN              NaN
# 4              Nick Adam  Person     Paris              NaN
# ...                  ...     ...       ...              ...
# 1745        Blaine Trump  Person  New York              NaN
# 1746        Robert Trump  Person  New York              NaN
# 1747   Ghislaine Maxwell  Person    London              NaN
# 1748     Jeffrey Epstein  Person       NaN              NaN
# 1749        Aboff Shelly  Person       NaN              NaN
#
#           Associated Entity
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
# ...                     ...
# 1745  Trump Management Inc.
# ...

# %%
merged_df = pd.merge(df1, df2, on=['Name','Type', 'City', 'Associated Entity', 'Associated Terms'], how='outer')

# %%
merged_df
# Out:
#                    Name           Type             City  \
# 0     301 East 66th St.  Miscellaneous         New York
# 1           Dan Abraham         Person         New York
# 2       Frederick Adler         Person  West Palm Beach
# 3            Cath Adler         Person  West Palm Beach
# 4          Aero Leasing         Entity   Zurich, Geneva
# ...                 ...            ...              ...
# 2072    Princess Firyal         Person         New York
# 2073      Lucy Wastnage         Person        Hong Kong
# 2074       Blaine Trump         Person         New York
# 2075       Robert Trump         Person         New York
# 2076       Aboff Shelly         Person              NaN
#
#            Associated Entity Associated Terms
# 0                        NaN              NaN
# 1           Thompson Medical              NaN
# 2     Venad Management, Inc.              NaN
# 3     Venad Management, Inc.              NaN
# 4                        NaN              NaN
# ...

# %%
df_person = merged_df[merged_df['Type'] == 'Person']

# %%
df_person = df_person.reset_index()

# %%
df_person
# Out:
#       index             Name    Type              City  \
# 0         1      Dan Abraham  Person          New York
# 1         2  Frederick Adler  Person   West Palm Beach
# 2         3       Cath Adler  Person   West Palm Beach
# 3         5      John Alessi  Person  Royal Palm Beach
# 4         6      Ron Altbach  Person          New York
# ...     ...              ...     ...               ...
# 1809   2072  Princess Firyal  Person          New York
# 1810   2073    Lucy Wastnage  Person         Hong Kong
# 1811   2074     Blaine Trump  Person          New York
# 1812   2075     Robert Trump  Person          New York
# 1813   2076     Aboff Shelly  Person               NaN
#
#            Associated Entity  Associated Terms
# 0           Thompson Medical               NaN
# 1     Venad Management, Inc.               NaN
# 2     Venad Management, Inc.               NaN
# 3                        NaN  House maint. man
# 4                        HKM               NaN
# ...

# %%
df_city = df_person.dropna(subset=["City"]).reset_index()

# %%
df_city
# Out:
#       level_0  index             Name    Type              City  \
# 0           0      1      Dan Abraham  Person          New York
# 1           1      2  Frederick Adler  Person   West Palm Beach
# 2           2      3       Cath Adler  Person   West Palm Beach
# 3           3      5      John Alessi  Person  Royal Palm Beach
# 4           4      6      Ron Altbach  Person          New York
# ...       ...    ...              ...     ...               ...
# 1288     1806   2069  Christy Prunier  Person          New York
# 1289     1809   2072  Princess Firyal  Person          New York
# 1290     1810   2073    Lucy Wastnage  Person         Hong Kong
# 1291     1811   2074     Blaine Trump  Person          New York
# 1292     1812   2075     Robert Trump  Person          New York
#
#            Associated Entity  Associated Terms
# 0           Thompson Medical               NaN
# 1     Venad Management, Inc.               NaN
# 2     Venad Management, Inc.               NaN
# ...

# %%
df_ae = df_person.dropna(subset=["Associated Entity"]).reset_index()

# %%
df_ae
# Out:
#      level_0  index             Name    Type             City  \
# 0          0      1      Dan Abraham  Person         New York
# 1          1      2  Frederick Adler  Person  West Palm Beach
# 2          2      3       Cath Adler  Person  West Palm Beach
# 3          4      6      Ron Altbach  Person         New York
# 4          8     11      Jean Appelt  Person              NaN
# ..       ...    ...              ...     ...              ...
# 399     1784   2022    Geoffrey Kent  Person       Vero Beach
# 400     1790   2035      Gary Kerney  Person   Upper Marlboro
# 401     1791   2036      Rhonda King  Person          Stanley
# 402     1811   2074     Blaine Trump  Person         New York
# 403     1812   2075     Robert Trump  Person         New York
#
#           Associated Entity Associated Terms
# 0          Thompson Medical              NaN
# 1    Venad Management, Inc.              NaN
# 2    Venad Management, Inc.              NaN
# ...

# %%
merged_df.to_csv(path + 'epstein_merged.csv', index=True)

# %%
df_city.to_csv(path + 'black_books_city.csv', index=True)

# %%
df_ae.to_csv(path + 'black_books_ae.csv', index=True)

# %% [markdown]
# <a href="https://colab.research.google.com/github/lucia1299/TheCrabTeam/blob/main/clean_flights_partII.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

my_flights = pd.read_excel("/content/flights_cleaned.xlsx")

new_df = pd.DataFrame(columns=my_flights.columns)

for index, row in my_flights.iterrows():
    passenger_list = [passenger.strip() for passenger in row['passengers'].split(',')]

    if len(passenger_list) == 1:
        my_flights = my_flights.drop(index)

    for passenger in passenger_list:
        new_row = row.copy()
        new_row['passengers'] = passenger
        new_df = new_df.append(new_row, ignore_index=True)
# Out:
# <ipython-input-24-d94a77db1052>:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df = new_df.append(new_row, ignore_index=True)
# <ipython-input-24-d94a77db1052>:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df = new_df.append(new_row, ignore_index=True)
# <ipython-input-24-d94a77db1052>:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df = new_df.append(new_row, ignore_index=True)
# <ipython-input-24-d94a77db1052>:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df = new_df.append(new_row, ignore_index=True)
# ...

# %%
new_df
# Out:
#          Date  year tail number                   from   \
# 0     Nov. 20  1995       N908JE  West Palm Beach (PBI)
# 1     Nov. 20  1995       N908JE  West Palm Beach (PBI)
# 2     Nov. 21  1995       N908JE        Teterboro (TEB)
# 3     Nov. 21  1995       N908JE        Teterboro (TEB)
# 4     Nov. 21  1995       N908JE        Teterboro (TEB)
# ...       ...   ...          ...                    ...
# 5423   Aug. 1  2013       N909JE        Teterboro (TEB)
# 5424   Aug. 3  2013       N909JE      Albuquerque (ABQ)
# 5425   Aug. 4  2013       N909JE        Las Vegas (LAS)
# 5426   Aug. 7  2013       N909JE      Albuquerque (ABQ)
# 5427   Aug. 7  2013       N909JE            Aspen (ASE)
#
#                         to      passengers  notes   ambiguours   \
# 0           Teterboro (TEB)             JE     NaN          NaN
# 1           Teterboro (TEB)             AS     NaN          NaN
# 2     West Palm Beach (PBI)             JE     NaN          NaN
# ...

# %%
import re

# %%
pattern = r'(BABY)|(\b\w+\b\?)|(\?+)|(\d)|(\b\w+\b\s\?)|(\b\w+\b\s\b\w+\b\?)|(.+?\?)|(AND \d PAX)|(\+ \d PAX)|((\w+(?:\s+\w+)*\s*\+\s*\d+(?:\s+\w+)*)+)'

filtered_df = new_df[~new_df['passengers'].str.match(pattern)]
filtered_df
# Out:
#          Date  year tail number                   from   \
# 3     Nov. 21  1995       N908JE        Teterboro (TEB)
# 4     Nov. 21  1995       N908JE        Teterboro (TEB)
# 5     Nov. 21  1995       N908JE        Teterboro (TEB)
# 8     Nov. 26  1995       N908JE  West Palm Beach (PBI)
# 9     Nov. 26  1995       N908JE  West Palm Beach (PBI)
# ...       ...   ...          ...                    ...
# 5423   Aug. 1  2013       N909JE        Teterboro (TEB)
# 5424   Aug. 3  2013       N909JE      Albuquerque (ABQ)
# 5425   Aug. 4  2013       N909JE        Las Vegas (LAS)
# 5426   Aug. 7  2013       N909JE      Albuquerque (ABQ)
# 5427   Aug. 7  2013       N909JE            Aspen (ASE)
#
#                         to      passengers  notes   ambiguours   \
# 3     West Palm Beach (PBI)             AS     NaN          NaN
# 4     West Palm Beach (PBI)            EVA     NaN          NaN
# 5     West Palm Beach (PBI)          GLENN     NaN          NaN
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
path = 'drive/MyDrive/'

# %%
filtered_df.to_csv(path + 'FINALE2_flights.csv', index=True)
